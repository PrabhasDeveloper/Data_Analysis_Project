# %% [markdown]
# # Government dataset-Agricultue Marketing and co-operation Department
# # This dataset contains 6,376 records with 16 columns, primarily related to agricultural market transactions.
# # dataset:-govtdataset.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import math

df=pd.read_csv("govtdataset.csv")
df
# Out:
#                           DDate  AmcCode       AmcName  YardCode  \
# 0     2025-02-01 00:00:00+05:30      324    Bowenpally         3
# 1     2025-02-01 00:00:00+05:30      323  Gaddiannaram         2
# 2     2025-02-01 00:00:00+05:30      325     Hyderabad         6
# 3     2025-02-01 00:00:00+05:30      325     Hyderabad         5
# 4     2025-02-01 00:00:00+05:30      325     Hyderabad         7
# ...                         ...      ...           ...       ...
# 6371  2025-02-24 00:00:00+05:30      246      Warangal       886
# 6372  2025-02-23 00:00:00+05:30      246      Warangal       886
# 6373  2025-02-27 00:00:00+05:30      246      Warangal       886
# 6374  2025-02-25 00:00:00+05:30      246      Warangal       886
# 6375  2025-02-26 00:00:00+05:30      246      Warangal       886
#
#             YardName  CommCode       CommName  VarityCode VarityName  \
# 0         Bowenpally        55         Onions          55     Common
# ...

# %% [markdown]
# # Loaded the dataset: Read the CSV file (`govtdataset.csv`) using `pd.read_csv()` and displayed the dataset.

# %%
df.head(3)
# Out:
#                        DDate  AmcCode       AmcName  YardCode     YardName  \
# 0  2025-02-01 00:00:00+05:30      324    Bowenpally         3   Bowenpally
# 1  2025-02-01 00:00:00+05:30      323  Gaddiannaram         2    L.B Nagar
# 2  2025-02-01 00:00:00+05:30      325     Hyderabad         6  Madannapeta
#
#    CommCode CommName  VarityCode VarityName  ProgArrivals  Arrivals  Minimum  \
# 0        55   Onions          55     Common           0.0     892.0    800.0
# 1        98  Cabbage          98     Common           0.0      87.0    800.0
# 2        98  Cabbage          98     Common           0.0      20.0    800.0
#
#    Maximum   Model  Valuation  MarketFee
# 0   3000.0  2400.0        0.0        0.0
# 1   1000.0   900.0        0.0        0.0
# 2   1200.0  1000.0        0.0        0.0

# %% [markdown]
# # Displayed the first 3 rows of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6376 entries, 0 to 6375
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DDate         6376 non-null   object
#  1   AmcCode       6376 non-null   int64
#  2   AmcName       6376 non-null   object
#  3   YardCode      6376 non-null   int64
#  4   YardName      6376 non-null   object
#  5   CommCode      6376 non-null   int64
#  6   CommName      6376 non-null   object
#  7   VarityCode    6376 non-null   int64
#  8   VarityName    6376 non-null   object
#  9   ProgArrivals  6376 non-null   float64
#  10  Arrivals      6376 non-null   float64
#  11  Minimum       6376 non-null   float64
#  12  Maximum       6376 non-null   float64
#  13  Model         6376 non-null   float64
#  14  Valuation     6376 non-null   float64
#  15  MarketFee     6376 non-null   float64
# dtypes: float64(7), int64(4), object(5)
# memory usage: 797.1+ KB

# %% [markdown]
# # Checked dataset information: Displayed column types and non-null counts using `df.info()`.

# %%
df["DDate"] = pd.to_datetime(df["DDate"], errors='coerce')
df
# Out:
#                          DDate  AmcCode       AmcName  YardCode  \
# 0    2025-02-01 00:00:00+05:30      324    Bowenpally         3
# 1    2025-02-01 00:00:00+05:30      323  Gaddiannaram         2
# 2    2025-02-01 00:00:00+05:30      325     Hyderabad         6
# 3    2025-02-01 00:00:00+05:30      325     Hyderabad         5
# 4    2025-02-01 00:00:00+05:30      325     Hyderabad         7
# ...                        ...      ...           ...       ...
# 6371 2025-02-24 00:00:00+05:30      246      Warangal       886
# 6372 2025-02-23 00:00:00+05:30      246      Warangal       886
# 6373 2025-02-27 00:00:00+05:30      246      Warangal       886
# 6374 2025-02-25 00:00:00+05:30      246      Warangal       886
# 6375 2025-02-26 00:00:00+05:30      246      Warangal       886
#
#             YardName  CommCode       CommName  VarityCode VarityName  \
# 0         Bowenpally        55         Onions          55     Common
# ...

# %%
df = df.drop_duplicates()
df
# Out:
#                          DDate  AmcCode       AmcName  YardCode  \
# 0    2025-02-01 00:00:00+05:30      324    Bowenpally         3
# 1    2025-02-01 00:00:00+05:30      323  Gaddiannaram         2
# 2    2025-02-01 00:00:00+05:30      325     Hyderabad         6
# 3    2025-02-01 00:00:00+05:30      325     Hyderabad         5
# 4    2025-02-01 00:00:00+05:30      325     Hyderabad         7
# ...                        ...      ...           ...       ...
# 6371 2025-02-24 00:00:00+05:30      246      Warangal       886
# 6372 2025-02-23 00:00:00+05:30      246      Warangal       886
# 6373 2025-02-27 00:00:00+05:30      246      Warangal       886
# 6374 2025-02-25 00:00:00+05:30      246      Warangal       886
# 6375 2025-02-26 00:00:00+05:30      246      Warangal       886
#
#             YardName  CommCode       CommName  VarityCode VarityName  \
# 0         Bowenpally        55         Onions          55     Common
# ...

# %% [markdown]
# # Removed duplicate entries and Cleaned the dataset by dropping duplicate rows.

# %%
df.fillna(0, inplace=True)
df
# Out:
#                          DDate  AmcCode       AmcName  YardCode  \
# 0    2025-02-01 00:00:00+05:30      324    Bowenpally         3
# 1    2025-02-01 00:00:00+05:30      323  Gaddiannaram         2
# 2    2025-02-01 00:00:00+05:30      325     Hyderabad         6
# 3    2025-02-01 00:00:00+05:30      325     Hyderabad         5
# 4    2025-02-01 00:00:00+05:30      325     Hyderabad         7
# ...                        ...      ...           ...       ...
# 6371 2025-02-24 00:00:00+05:30      246      Warangal       886
# 6372 2025-02-23 00:00:00+05:30      246      Warangal       886
# 6373 2025-02-27 00:00:00+05:30      246      Warangal       886
# 6374 2025-02-25 00:00:00+05:30      246      Warangal       886
# 6375 2025-02-26 00:00:00+05:30      246      Warangal       886
#
#             YardName  CommCode       CommName  VarityCode VarityName  \
# 0         Bowenpally        55         Onions          55     Common
# ...

# %%
for col in ["Arrivals", "Minimum", "Maximum", "Model", "Valuation", "MarketFee"]:
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    df[col] = np.where((df[col] < lower_bound) | (df[col] > upper_bound), np.nan, df[col])

df
# Out:
#                          DDate  AmcCode       AmcName  YardCode  \
# 0    2025-02-01 00:00:00+05:30      324    Bowenpally         3
# 1    2025-02-01 00:00:00+05:30      323  Gaddiannaram         2
# 2    2025-02-01 00:00:00+05:30      325     Hyderabad         6
# 3    2025-02-01 00:00:00+05:30      325     Hyderabad         5
# 4    2025-02-01 00:00:00+05:30      325     Hyderabad         7
# ...                        ...      ...           ...       ...
# 6371 2025-02-24 00:00:00+05:30      246      Warangal       886
# 6372 2025-02-23 00:00:00+05:30      246      Warangal       886
# 6373 2025-02-27 00:00:00+05:30      246      Warangal       886
# 6374 2025-02-25 00:00:00+05:30      246      Warangal       886
# 6375 2025-02-26 00:00:00+05:30      246      Warangal       886
#
#             YardName  CommCode       CommName  VarityCode VarityName  \
# 0         Bowenpally        55         Onions          55     Common
# ...

# %% [markdown]
# # **Applied Outlier Removal (IQR Method):** Removed outliers from columns - Arrivals, Minimum, Maximum, Model, Valuation, and MarketFee.

# %% [markdown]
# df.dropna(inplace=True)
# df

# %%
plt.figure(figsize=(12,6))
sb.histplot(df['Arrivals'], bins=30, kde=True, color='blue')
plt.title('Distribution of Arrivals')
plt.xlabel('Arrivals')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
#  # Visualized Distribution of Arrivals and Created a histogram with KDE to analyze arrival distribution.

# %%
plt.figure(figsize=(12,6))
sb.lineplot(x=df['Minimum'], y=df['Maximum'],color='red')
plt.xlabel("Minimum Price")
plt.ylabel("Maximum Price")
plt.title("Price Range Relationship")
plt.show()

# %%
# Visualized Price Range Relationship: Created a line plot comparing Minimum and Maximum prices.

# %%
plt.figure(figsize=(14,7))
sb.countplot(y=df['CommName'], order=df['CommName'].value_counts().index[:10])
plt.title("Top 10 Commodities by Frequency")
plt.xlabel("Count")
plt.ylabel("Commodity Name")
plt.show()

# %% [markdown]
# # Visualized Top 10 Commodities: Generated a count plot for the most frequently recorded commodities.

# %%
plt.figure(figsize=(12,6))
sb.lineplot(x=df['DDate'], y=df['Arrivals'], color='green')
plt.xlabel("Date")
plt.ylabel("Arrivals")
plt.title("Time Series of Arrivals Over Time")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Visualized Time Series of Arrivals: Created a line plot showing the trend of arrivals over time.

# %%
sb.pairplot(df[['Arrivals', 'Minimum', 'Maximum', 'Model', 'Valuation', 'MarketFee']])
plt.show()

# %% [markdown]
# # Generated Pair Plot Analysis: Visualized relationships between Arrivals, Minimum, Maximum, and Model columns using seaborn.pairplot().

# %%
plt.figure(figsize=(12,6))
sb.lineplot(x=df['DDate'], y=df['Arrivals'], color='green')
plt.xlabel("Date")
plt.ylabel("Arrivals")
plt.title("Time Series of Arrivals Over Time")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Visualized Time Series of Arrivals Over Time: Created a line plot to show trends in commodity arrivals over time.

# %%
top_commodities = df.groupby("CommName")["Arrivals"].sum().nlargest(10)

# %%
plt.figure(figsize=(10,5))
top_commodities.plot(kind='bar', color='skyblue')
plt.title("Top 10 Commodities by Arrivals")
plt.xlabel("Commodity")
plt.ylabel("Total Arrivals")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Identified Top 10 Commodities by Arrivals: Aggregated data and displayed as a bar plot.

# %%
plt.figure(figsize=(8,8))
top_commodities.plot(kind='pie', autopct='%1.1f%%', cmap='viridis')
plt.title("Percentage Distribution of Top 10 Commodities by Arrivals")
plt.ylabel("") 
plt.show()

# %% [markdown]
# # Displayed Top 10 Commodities as Pie Chart: Showed percentage distribution of commodity arrivals.

# %%
plt.figure(figsize=(14,7))
sb.violinplot(x='CommName', y='Model', data=df, order=df['CommName'].value_counts().index[:10])
plt.xticks(rotation=45)
plt.xlabel("Commodity Name")
plt.ylabel("Model Price")
plt.title("Distribution of Model Prices by Commodity")
plt.show()

# %% [markdown]
# # Visualized Distribution of Model Prices by Commodity: Created a violin plot for top 10 most recorded commodities.

# %%
data=pd.read_csv('govtdataset.csv')
market_yard_arrivals = data.groupby('YardName')['Arrivals'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
market_yard_arrivals.head(10).plot(kind='bar', color='orange')
plt.title('Top 10 Market Yards by Total Arrivals')
plt.xlabel('Market Yard')
plt.ylabel('Total Arrivals')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Compared Prices Across Commodities: Displayed box plots for Minimum, Maximum, and Model prices for top commodities.

# %%
data['CommName'].value_counts().head(5).plot.pie(autopct='%1.1f%%', figsize=(8, 8), startangle=90)
plt.title('Top 5 Commodities by Record Count')
plt.ylabel('')
plt.show()

# %% [markdown]
# # Analyzed Monthly Trends in Arrivals: Grouped data by month to observe trends in arrivals over time.

# %%
plt.figure(figsize=(10, 6))
sb.histplot(data['Model'], bins=20, kde=True, color='purple')
plt.title('Distribution of Model Prices')
plt.xlabel('Model Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sb.scatterplot(data=data, x='Minimum', y='Maximum', hue='CommName', alpha=0.7)
plt.title('Scatter Plot: Minimum vs Maximum Prices by Commodity')
plt.xlabel('Minimum Price')
plt.ylabel('Maximum Price')
plt.legend(title='Commodity', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# # Scatter Plot of Minimum vs. Maximum Prices: Visualized the relationship between Minimum and Maximum prices for commodities.

# %%
plt.figure(figsize=(12, 6))
sb.boxplot(data=data, x='YardName', y='MarketFee', hue='YardName', dodge=False, palette='coolwarm')
plt.title('Market Fees by Yard')
plt.xlabel('Market Yard')
plt.ylabel('Market Fee')
plt.xticks(rotation=90) 
plt.legend([], [], frameon=False) 
plt.show()

# %%
pivot_table = data.pivot_table(index='YardName', columns='CommName', values='Arrivals', aggfunc='sum', fill_value=0)

pivot_table.head(10).plot(kind='bar', stacked=True, figsize=(12, 8), cmap='viridis')
plt.title('Stacked Bar Plot: Arrivals by Yard and Commodity')
plt.xlabel('Market Yard')
plt.ylabel('Total Arrivals')
plt.legend(title='Commodity', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
numerical_data = data.select_dtypes(include=['float64', 'int64'])
plt.figure(figsize=(10, 8))
sb.heatmap(numerical_data.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# # Heatmap of Price Correlations: Displayed correlations between Arrivals, Minimum, Maximum, and Model prices using a heatmap.

# %%
max_prices = data.groupby('CommName')['Maximum'].max().sort_values(ascending=False)
plt.figure(figsize=(12, 6))
max_prices.head(10).plot(kind='bar', color='gold') 
plt.title('Top 10 Commodities by Maximum Price')
plt.xlabel('Commodity')
plt.ylabel('Maximum Price')
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('govtdataset.csv')
subset = data[['CommName', 'Minimum', 'Maximum']].dropna().head(10)

plt.figure(figsize=(10, 6))
x = range(len(subset))
plt.bar(x, subset['Minimum'], color='beige', label='Minimum', alpha=0.8)
plt.bar(x, subset['Maximum'], color='tan', label='Maximum', alpha=0.8)
plt.xticks(x, subset['CommName'], rotation=45, ha='right')
plt.title('Minimum and Maximum Prices of Commodities', fontsize=14)
plt.ylabel('Price')
plt.xlabel('Commodity')
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.pie(subset['Maximum'], labels=subset['CommName'], autopct='%1.1f%%',
        colors=['#f5deb3', '#f0e68c', '#d2b48c', '#deb887', '#cdb79e',
                '#ffe4c4', '#e0c2a2', '#ecd9c6', '#d8bfd8', '#c9b59a'])
plt.title('Proportion of Maximum Prices', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Displayed Summary Statistics
